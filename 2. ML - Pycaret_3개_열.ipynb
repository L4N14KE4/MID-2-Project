# %% [markdown]
# # PyCaret 3개 열 사용 모델

# %%
# !pip install pycaret==3.0.0
# Out:
# Requirement already satisfied: pycaret==3.0.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (4.66.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.23.5)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5.3)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.1.2)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.11.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.3.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.2.2)
# Requirement already satisfied: pyod>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.10.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.6.2)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (4.0.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.56.4)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (6.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.9.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.7.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.15.0)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.2.1)
# Requirement already satisfied: schemdraw>=0.14 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.17)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.9.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.14.0)
# Requirement already satisfied: sktime>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.23.0)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.1.3)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.0.3)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.4.0->pycaret==3.0.0) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation>=2.1.0->pycaret==3.0.0) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn>=0.8.1->pycaret==3.0.0) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.12.0->pycaret==3.0.0) (3.17.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (2.8.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (4.19.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (5.3.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.0->pycaret==3.0.0) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret==3.0.0) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->pycaret==3.0.0) (8.2.3)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.13.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (3.9.7)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.0.9.1)
# Requirement already satisfied: tsdownsample==0.1.2 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (3.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (2.0.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod>=1.0.8->pycaret==3.0.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (2023.7.22)
# Requirement already satisfied: scikit-base<0.6.0 in /usr/local/lib/python3.10/dist-packages (from sktime>=0.16.1->pycaret==3.0.0) (0.5.2)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.5)
# Requirement already satisfied: Werkzeug<2.3.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (4.5.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.5.8)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.0.0) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (0.10.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret==3.0.0) (0.2.7)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret==3.0.0) (3.10.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (8.1.7)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.6.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.21)

# %%
from pycaret.classification import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
diabates = pd.read_csv('diabetes_generators.csv', index_col=0) # index번호 없앰
diabates.head()
# Out:
#    Glucose   BMI  Age  Outcome
# 0    148.0  33.6   50        1
# 1     85.0  26.6   31        0
# 2    183.0  23.3   32        1
# 3     89.0  28.1   21        0
# 4    137.0  43.1   33        1

# %%
diabates = diabates.astype(float)
diabates['Outcome'] = diabates['Outcome'].astype(int)  # 'Outcome' int로 되돌리기

# %%
diabates
# Out:
#      Glucose   BMI   Age  Outcome
# 0      148.0  33.6  50.0        1
# 1       85.0  26.6  31.0        0
# 2      183.0  23.3  32.0        1
# 3       89.0  28.1  21.0        0
# 4      137.0  43.1  33.0        1
# ..       ...   ...   ...      ...
# 763    101.0  32.9  63.0        0
# 764    122.0  36.8  27.0        0
# 765    121.0  26.2  30.0        0
# 766    126.0  30.1  47.0        1
# 767     93.0  30.4  23.0        0
#
# [768 rows x 4 columns]

# %% [markdown]
# #### Standadardization - Robert Scaler

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler

# 숫자형 변수들의 이름 리스트
numeric_columns = ['Age', 'BMI', 'Glucose']

# RobustScaler 사용 전처리기 정의
preprocessor = ColumnTransformer(
    transformers=[('numeric', RobustScaler(), numeric_columns)]
)

# 파이프라인에 추가
preprocessor_pipe = Pipeline(steps=[('preprocessor', preprocessor)]) # preprocessing-only

# fit & transform
preprocessor_pipe.fit(diabates)
diabates_transformed = preprocessor_pipe.transform(diabates)

# DataFrame로 변환 & 컬럼 이름 재지정
diabates_transformed = pd.DataFrame(diabates_transformed)
diabates_transformed.columns = ['Age', 'BMI', 'Glucose']
diabates_transformed['Outcome'] = diabates['Outcome']

diabates_transformed.head(3)
# Out:
#         Age       BMI   Glucose  Outcome
# 0  1.235294  0.142857  0.765432        1
# 1  0.117647 -0.626374 -0.790123        0
# 2  0.176471 -0.989011  1.629630        1

# %%
# PyCaret setup 함수로 실험 환경 설정: 훈련 데이터와 목표 변수, 훈련 세트 크기 등 설정
model = setup(data=diabates_transformed,
              target='Outcome',
              train_size=0.7,
              # normalize=True,
              session_id=9)
# Out:
# <style type="text/css">
# #T_7c592_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c592" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c592_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c592_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c592_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c592_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c592_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c592_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c592_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c592_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7c592_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c592_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7c592_row3_col1" class="data row3 col1" >(768, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c592_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7c592_row4_col1" class="data row4 col1" >(768, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c592_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7c592_row5_col1" class="data row5 col1" >(537, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c592_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7c592_row6_col1" class="data row6 col1" >(231, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c592_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7c592_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c592_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_7c592_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c592_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_7c592_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c592_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_7c592_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c592_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_7c592_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c592_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_7c592_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c592_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_7c592_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c592_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_7c592_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c592_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_7c592_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c592_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_7c592_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c592_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_7c592_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7c592_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c592_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_7c592_row18_col1" class="data row18 col1" >df6f</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Accuracy 기준 top 3 모델 선택
top_3_models = compare_models(sort='Accuracy',
                              n_select = 3) # Select top n models
# Out:
# <style type="text/css">
# #T_0de9c th {
#   text-align: left;
# }
# #T_0de9c_row0_col0, #T_0de9c_row0_col2, #T_0de9c_row0_col3, #T_0de9c_row0_col5, #T_0de9c_row1_col0, #T_0de9c_row1_col1, #T_0de9c_row1_col3, #T_0de9c_row1_col4, #T_0de9c_row1_col6, #T_0de9c_row1_col7, #T_0de9c_row2_col0, #T_0de9c_row2_col1, #T_0de9c_row2_col2, #T_0de9c_row2_col3, #T_0de9c_row2_col4, #T_0de9c_row2_col5, #T_0de9c_row2_col6, #T_0de9c_row2_col7, #T_0de9c_row3_col0, #T_0de9c_row3_col1, #T_0de9c_row3_col2, #T_0de9c_row3_col3, #T_0de9c_row3_col4, #T_0de9c_row3_col5, #T_0de9c_row3_col6, #T_0de9c_row3_col7, #T_0de9c_row4_col0, #T_0de9c_row4_col1, #T_0de9c_row4_col2, #T_0de9c_row4_col3, #T_0de9c_row4_col4, #T_0de9c_row4_col5, #T_0de9c_row4_col6, #T_0de9c_row4_col7, #T_0de9c_row5_col0, #T_0de9c_row5_col1, #T_0de9c_row5_col2, #T_0de9c_row5_col3, #T_0de9c_row5_col4, #T_0de9c_row5_col5, #T_0de9c_row5_col6, #T_0de9c_row5_col7, #T_0de9c_row6_col0, #T_0de9c_row6_col1, #T_0de9c_row6_col2, #T_0de9c_row6_col3, #T_0de9c_row6_col4, #T_0de9c_row6_col5, #T_0de9c_row6_col6, #T_0de9c_row6_col7, #T_0de9c_row7_col0, #T_0de9c_row7_col1, #T_0de9c_row7_col2, #T_0de9c_row7_col3, #T_0de9c_row7_col4, #T_0de9c_row7_col5, #T_0de9c_row7_col6, #T_0de9c_row7_col7, #T_0de9c_row8_col0, #T_0de9c_row8_col1, #T_0de9c_row8_col2, #T_0de9c_row8_col3, #T_0de9c_row8_col4, #T_0de9c_row8_col5, #T_0de9c_row8_col6, #T_0de9c_row8_col7, #T_0de9c_row9_col0, #T_0de9c_row9_col1, #T_0de9c_row9_col2, #T_0de9c_row9_col3, #T_0de9c_row9_col4, #T_0de9c_row9_col5, #T_0de9c_row9_col6, #T_0de9c_row9_col7, #T_0de9c_row10_col0, #T_0de9c_row10_col1, #T_0de9c_row10_col2, #T_0de9c_row10_col3, #T_0de9c_row10_col4, #T_0de9c_row10_col5, #T_0de9c_row10_col6, #T_0de9c_row10_col7, #T_0de9c_row11_col0, #T_0de9c_row11_col1, #T_0de9c_row11_col2, #T_0de9c_row11_col3, #T_0de9c_row11_col4, #T_0de9c_row11_col5, #T_0de9c_row11_col6, #T_0de9c_row11_col7, #T_0de9c_row12_col0, #T_0de9c_row12_col1, #T_0de9c_row12_col2, #T_0de9c_row12_col3, #T_0de9c_row12_col4, #T_0de9c_row12_col5, #T_0de9c_row12_col6, #T_0de9c_row12_col7, #T_0de9c_row13_col0, #T_0de9c_row13_col1, #T_0de9c_row13_col2, #T_0de9c_row13_col4, #T_0de9c_row13_col5, #T_0de9c_row13_col6, #T_0de9c_row13_col7, #T_0de9c_row14_col0, #T_0de9c_row14_col1, #T_0de9c_row14_col2, #T_0de9c_row14_col3, #T_0de9c_row14_col4, #T_0de9c_row14_col5, #T_0de9c_row14_col6, #T_0de9c_row14_col7 {
#   text-align: left;
# }
# #T_0de9c_row0_col1, #T_0de9c_row0_col4, #T_0de9c_row0_col6, #T_0de9c_row0_col7, #T_0de9c_row1_col2, #T_0de9c_row1_col5, #T_0de9c_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0de9c_row0_col8, #T_0de9c_row1_col8, #T_0de9c_row3_col8, #T_0de9c_row4_col8, #T_0de9c_row5_col8, #T_0de9c_row6_col8, #T_0de9c_row7_col8, #T_0de9c_row8_col8, #T_0de9c_row9_col8, #T_0de9c_row10_col8, #T_0de9c_row11_col8, #T_0de9c_row12_col8, #T_0de9c_row13_col8, #T_0de9c_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0de9c_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0de9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0de9c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0de9c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0de9c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0de9c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0de9c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0de9c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0de9c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0de9c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0de9c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0de9c_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_0de9c_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_0de9c_row0_col1" class="data row0 col1" >0.7748</td>
#       <td id="T_0de9c_row0_col2" class="data row0 col2" >0.8307</td>
#       <td id="T_0de9c_row0_col3" class="data row0 col3" >0.5620</td>
#       <td id="T_0de9c_row0_col4" class="data row0 col4" >0.7402</td>
#       <td id="T_0de9c_row0_col5" class="data row0 col5" >0.6327</td>
#       <td id="T_0de9c_row0_col6" class="data row0 col6" >0.4758</td>
#       <td id="T_0de9c_row0_col7" class="data row0 col7" >0.4891</td>
#       <td id="T_0de9c_row0_col8" class="data row0 col8" >0.7760</td>
#     </tr>
#     <tr>
#       <th id="T_0de9c_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_0de9c_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_0de9c_row1_col1" class="data row1 col1" >0.7729</td>
#       <td id="T_0de9c_row1_col2" class="data row1 col2" >0.8313</td>
#       <td id="T_0de9c_row1_col3" class="data row1 col3" >0.5728</td>
#       <td id="T_0de9c_row1_col4" class="data row1 col4" >0.7248</td>
#       <td id="T_0de9c_row1_col5" class="data row1 col5" >0.6338</td>
#       <td id="T_0de9c_row1_col6" class="data row1 col6" >0.4740</td>
#       <td id="T_0de9c_row1_col7" class="data row1 col7" >0.4847</td>
#       <td id="T_0de9c_row1_col8" class="data row1 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_0de9c_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_0de9c_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_0de9c_row2_col1" class="data row2 col1" >0.7710</td>
#       <td id="T_0de9c_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_0de9c_row2_col3" class="data row2 col3" >0.5564</td>
#       <td id="T_0de9c_row2_col4" class="data row2 col4" >0.7315</td>
#       <td id="T_0de9c_row2_col5" class="data row2 col5" >0.6258</td>
#       <td id="T_0de9c_row2_col6" class="data row2 col6" >0.4666</td>
#       <td id="T_0de9c_row2_col7" class="data row2 col7" >0.4794</td>
#       <td id="T_0de9c_row2_col8" class="data row2 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_0de9c_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_0de9c_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0de9c_row3_col1" class="data row3 col1" >0.7710</td>
#       <td id="T_0de9c_row3_col2" class="data row3 col2" >0.8300</td>
#       <td id="T_0de9c_row3_col3" class="data row3 col3" >0.5620</td>
#       <td id="T_0de9c_row3_col4" class="data row3 col4" >0.7259</td>
#       <td id="T_0de9c_row3_col5" class="data row3 col5" >0.6275</td>
#       <td id="T_0de9c_row3_col6" class="data row3 col6" >0.4676</td>
#       <td id="T_0de9c_row3_col7" class="data row3 col7" >0.4792</td>
#       <td id="T_0de9c_row3_col8" class="data row3 col8" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_0de9c_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_0de9c_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_0de9c_row4_col1" class="data row4 col1" >0.7673</td>
#       <td id="T_0de9c_row4_col2" class="data row4 col2" >0.8209</td>
#       <td id="T_0de9c_row4_col3" class="data row4 col3" >0.5564</td>
#       <td id="T_0de9c_row4_col4" class="data row4 col4" >0.7177</td>
#       <td id="T_0de9c_row4_col5" class="data row4 col5" >0.6225</td>
#       <td id="T_0de9c_row4_col6" class="data row4 col6" >0.4593</td>
#       <td id="T_0de9c_row4_col7" class="data row4 col7" >0.4697</td>
#       <td id="T_0de9c_row4_col8" class="data row4 col8" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_0de9c_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_0de9c_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0de9c_row5_col1" class="data row5 col1" >0.7505</td>
#       <td id="T_0de9c_row5_col2" class="data row5 col2" >0.7988</td>
#       <td id="T_0de9c_row5_col3" class="data row5 col3" >0.6047</td>
#       <td id="T_0de9c_row5_col4" class="data row5 col4" >0.6554</td>
#       <td id="T_0de
# Processing:   0%|          | 0/67 [00:00<?, ?it/s]

# %%
# 3개 모델 조합
blended = blend_models(estimator_list=top_3_models,
                       fold=10, # default
                       optimize='Accuracy',
                       method = 'hard')
# Out:
# <style type="text/css">
# #T_c7655_row10_col0, #T_c7655_row10_col1, #T_c7655_row10_col2, #T_c7655_row10_col3, #T_c7655_row10_col4, #T_c7655_row10_col5, #T_c7655_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c7655" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7655_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c7655_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c7655_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c7655_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c7655_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c7655_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c7655_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7655_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7655_row0_col0" class="data row0 col0" >0.7407</td>
#       <td id="T_c7655_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_c7655_row0_col2" class="data row0 col2" >0.4737</td>
#       <td id="T_c7655_row0_col3" class="data row0 col3" >0.6923</td>
#       <td id="T_c7655_row0_col4" class="data row0 col4" >0.5625</td>
#       <td id="T_c7655_row0_col5" class="data row0 col5" >0.3874</td>
#       <td id="T_c7655_row0_col6" class="data row0 col6" >0.4014</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7655_row1_col0" class="data row1 col0" >0.7593</td>
#       <td id="T_c7655_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_c7655_row1_col2" class="data row1 col2" >0.5789</td>
#       <td id="T_c7655_row1_col3" class="data row1 col3" >0.6875</td>
#       <td id="T_c7655_row1_col4" class="data row1 col4" >0.6286</td>
#       <td id="T_c7655_row1_col5" class="data row1 col5" >0.4524</td>
#       <td id="T_c7655_row1_col6" class="data row1 col6" >0.4561</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7655_row2_col0" class="data row2 col0" >0.7407</td>
#       <td id="T_c7655_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_c7655_row2_col2" class="data row2 col2" >0.4211</td>
#       <td id="T_c7655_row2_col3" class="data row2 col3" >0.7273</td>
#       <td id="T_c7655_row2_col4" class="data row2 col4" >0.5333</td>
#       <td id="T_c7655_row2_col5" class="data row2 col5" >0.3710</td>
#       <td id="T_c7655_row2_col6" class="data row2 col6" >0.3976</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7655_row3_col0" class="data row3 col0" >0.7593</td>
#       <td id="T_c7655_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_c7655_row3_col2" class="data row3 col2" >0.4737</td>
#       <td id="T_c7655_row3_col3" class="data row3 col3" >0.7500</td>
#       <td id="T_c7655_row3_col4" class="data row3 col4" >0.5806</td>
#       <td id="T_c7655_row3_col5" class="data row3 col5" >0.4236</td>
#       <td id="T_c7655_row3_col6" class="data row3 col6" >0.4456</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7655_row4_col0" class="data row4 col0" >0.8889</td>
#       <td id="T_c7655_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_c7655_row4_col2" class="data row4 col2" >0.7368</td>
#       <td id="T_c7655_row4_col3" class="data row4 col3" >0.9333</td>
#       <td id="T_c7655_row4_col4" class="data row4 col4" >0.8235</td>
#       <td id="T_c7655_row4_col5" class="data row4 col5" >0.7441</td>
#       <td id="T_c7655_row4_col6" class="data row4 col6" >0.7551</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7655_row5_col0" class="data row5 col0" >0.7037</td>
#       <td id="T_c7655_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_c7655_row5_col2" class="data row5 col2" >0.6316</td>
#       <td id="T_c7655_row5_col3" class="data row5 col3" >0.5714</td>
#       <td id="T_c7655_row5_col4" class="data row5 col4" >0.6000</td>
#       <td id="T_c7655_row5_col5" class="data row5 col5" >0.3656</td>
#       <td id="T_c7655_row5_col6" class="data row5 col6" >0.3668</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7655_row6_col0" class="data row6 col0" >0.7593</td>
#       <td id="T_c7655_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_c7655_row6_col2" class="data row6 col2" >0.5263</td>
#       <td id="T_c7655_row6_col3" class="data row6 col3" >0.7143</td>
#       <td id="T_c7655_row6_col4" class="data row6 col4" >0.6061</td>
#       <td id="T_c7655_row6_col5" class="data row6 col5" >0.4384</td>
#       <td id="T_c7655_row6_col6" class="data row6 col6" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7655_row7_col0" class="data row7 col0" >0.7925</td>
#       <td id="T_c7655_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_c7655_row7_col2" class="data row7 col2" >0.6667</td>
#       <td id="T_c7655_row7_col3" class="data row7 col3" >0.7059</td>
#       <td id="T_c7655_row7_col4" class="data row7 col4" >0.6857</td>
#       <td id="T_c7655_row7_col5" class="data row7 col5" >0.5310</td>
#       <td id="T_c7655_row7_col6" class="data row7 col6" >0.5315</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7655_row8_col0" class="data row8 col0" >0.7925</td>
#       <td id="T_c7655_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_c7655_row8_col2" class="data row8 col2" >0.6111</td>
#       <td id="T_c7655_row8_col3" class="data row8 col3" >0.7333</td>
#       <td id="T_c7655_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_c7655_row8_col5" class="data row8 col5" >0.5178</td>
#       <td id="T_c7655_row8_col6" class="data row8 col6" >0.5223</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7655_row9_col0" class="data row9 col0" >0.7925</td>
#       <td id="T_c7655_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_c7655_row9_col2" class="data row9 col2" >0.5000</td>
#       <td id="T_c7655_row9_col3" class="data row9 col3" >0.8182</td>
#       <td id="T_c7655_row9_col4" class="data row9 col4" >0.6207</td>
#       <td id="T_c7655_row9_col5" class="data row9 col5" >0.4890</td>
#       <td id="T_c7655_row9_col6" class="data row9 col6" >0.5171</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c7655_row10_col0" class="data row10 col0" >0.7729</td>
#       <td id="T_c7655_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_c7655_row10_col2" class="data row10 col2" >0.5620</td>
#       <td id="T_c7655_row10_col3" class="data row10 col3" >0.7334</td>
#       <td id="T_c7655_row10_col4" class="data row10 col4" >0.6308</td>
#       <td id="T_c7655_row10_col5" class="data row10 col5" >0.4720</td>
#       <td id="T_c7655_row10_col6" class="data row10 col6" >0.4843</td>
#     </tr>
#     <tr>
#       <th id="T_c7655_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c7655_row11_col0" class="data row11 col0" >0.0469</td>
#       <td id="T_c7655_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_c7655_row11_col2" class="data row11 col2" >0.0947</td>
#       <td id="T_c7655_row11_col3" class="data row11 col3" >0.0887</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# 조합 모델 예측 수행
predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fda13" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda13_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fda13_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fda13_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fda13_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fda13_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fda13_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fda13_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fda13_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fda13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fda13_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_fda13_row0_col1" class="data row0 col1" >0.7662</td>
#       <td id="T_fda13_row0_col2" class="data row0 col2" >0.7149</td>
#       <td id="T_fda13_row0_col3" class="data row0 col3" >0.5432</td>
#       <td id="T_fda13_row0_col4" class="data row0 col4" >0.7213</td>
#       <td id="T_fda13_row0_col5" class="data row0 col5" >0.6197</td>
#       <td id="T_fda13_row0_col6" class="data row0 col6" >0.4558</td>
#       <td id="T_fda13_row0_col7" class="data row0 col7" >0.4653</td>
#     </tr>
#   </tbody>
# </table>
#           Age       BMI   Glucose  Outcome  prediction_label
# 223  1.882353 -0.384615  0.617284        0                 1
# 537  2.235294 -1.164835 -1.481481        0                 0
# 109 -0.294118  0.560440 -0.543210        1                 0
# 716  0.117647  0.164835  1.382716        1                 1
# 49  -0.294118  0.000000 -0.296296        0                 0
# ..        ...       ...       ...      ...               ...
# 253 -0.235294  0.384615 -0.765432        0                 0
# 176  0.764706 -0.120879 -0.790123        0                 0
# 743  0.941176  0.043956  0.567901        1                 1
# 173 -0.352941  1.230769 -0.938272        0                 0
# 335 -0.176471  1.714286  1.185185        0                 1
#
# [231 rows x 5 columns]

# %%
# 최종 모델 확정
final_blended = finalize_model(blended)
print(final_blended)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Age', 'BMI', 'Glucose'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecated'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=No...
#                                                                   tol=0.0001,
#                                                                   verbose=0,
#                                                                   warm_start=False)),
#                                               ('Naive Bayes',
#                                                GaussianNB(priors=None,
#                                                           var_smoothing=1e-09)),
#                                               ('Ridge Classifier',
#                                                RidgeClassifier(alpha=1.0,
#                                                                class_weight=None,
#                                                                copy_X=True,
#                                                                fit_intercept=True,
#                                                                max_iter=None,
#                                                                positive=False,
#                                                                random_state=9,
#                                                                solver='auto',
#                                                                tol=0.0001))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='hard',
#                                   weights=None))],
#          verbose=False)

# %%
# 최종 모델로 예측 수행
predict_model(final_blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06dd5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06dd5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_06dd5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_06dd5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_06dd5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_06dd5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_06dd5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_06dd5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_06dd5_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06dd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06dd5_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_06dd5_row0_col1" class="data row0 col1" >0.7662</td>
#       <td id="T_06dd5_row0_col2" class="data row0 col2" >0.7149</td>
#       <td id="T_06dd5_row0_col3" class="data row0 col3" >0.5432</td>
#       <td id="T_06dd5_row0_col4" class="data row0 col4" >0.7213</td>
#       <td id="T_06dd5_row0_col5" class="data row0 col5" >0.6197</td>
#       <td id="T_06dd5_row0_col6" class="data row0 col6" >0.4558</td>
#       <td id="T_06dd5_row0_col7" class="data row0 col7" >0.4653</td>
#     </tr>
#   </tbody>
# </table>
#           Age       BMI   Glucose  Outcome  prediction_label
# 223  1.882353 -0.384615  0.617284        0                 1
# 537  2.235294 -1.164835 -1.481481        0                 0
# 109 -0.294118  0.560440 -0.543210        1                 0
# 716  0.117647  0.164835  1.382716        1                 1
# 49  -0.294118  0.000000 -0.296296        0                 0
# ..        ...       ...       ...      ...               ...
# 253 -0.235294  0.384615 -0.765432        0                 0
# 176  0.764706 -0.120879 -0.790123        0                 0
# 743  0.941176  0.043956  0.567901        1                 1
# 173 -0.352941  1.230769 -0.938272        0                 0
# 335 -0.176471  1.714286  1.185185        0                 1
#
# [231 rows x 5 columns]

# %% [markdown]
# ##### 모델 예측 테스트

# %%
sample_data = pd.DataFrame([[171, 45.4, 54]], columns=['Glucose', 'BMI', 'Age'])
final_blended.predict(sample_data)
# Out:
# array([1], dtype=int8)

# %% [markdown]
# #### 모델 저장

# %%
save_model(final_blended, 'final_blended_3')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'BMI', 'Glucose'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=No...
#                                                                    tol=0.0001,
#                                                                    verbose=0,
#                                                                    warm_start=False)),
#                                                ('Naive Bayes',
#                                                 GaussianNB(priors=None,
#                                                            var_smoothing=1e-09)),
#                                                ('Ridge Classifier',
#                                                 RidgeClassifier(alpha=1.0,
#                                                                 class_weight=None,
#                                                                 copy_X=True,
#                                                                 fit_intercept=True,
#                                                                 max_iter=None,
#                                                                 positive=False,
#                                                                 random_state=9,
#                                                                 solver='auto',
#                                                                 tol=0.0001))],
#                                    flatten_transform=True, n_jobs=-1,
#                                    verbose=False, voting='hard',
#                                    weights=None))],
#           verbose=False),
#  'final_blended_3.pkl')

# %% [markdown]
# ### 성능 측정
# 파일 "2. ML.jpynb" 에서 가져온 x_test_df.csv, y_test_df.csv 불러오기(x_test_transformed, y_test)

# %%
# !pip install pycaret
import joblib
import numpy as np
import pandas as pd
import sklearn

from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

model_loaded = load_model('final_blended_3')

x_test_df = pd.read_csv('x_test_df.csv', index_col=0)
y_test = pd.read_csv('y_test_df.csv', index_col=0)

# hard 투표 방식으로 predict_proba 사용 불가능 & ROC AUC 계산불가
pred = model_loaded.predict(x_test_df)
# pred_proba = model_loaded.predict_proba(x_test_df)[:, 1]

confusion_without = confusion_matrix(y_test, pred)
accuracy_without = accuracy_score(y_test, pred)
precision_without = precision_score(y_test, pred)
recall_without = recall_score(y_test, pred)
f1_without = f1_score(y_test, pred)
# roc_auc_without = roc_auc_score(y_test, pred_proba)

print('Confusion matrix:')
print(confusion_without)
print()

print('Accuracy :', accuracy_without)
print('Precision :', precision_without)
print('Recall :', recall_without)
print('F1 :', f1_without)
# print('ROC_AUC :', roc_auc_without)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Confusion matrix:
# [[133  24]
#  [ 42  32]]
#
# Accuracy : 0.7142857142857143
# Precision : 0.5714285714285714
# Recall : 0.43243243243243246
# F1 : 0.49230769230769234

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=645823d6-5f8a-49f6-b0db-26e2163dbcc0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
